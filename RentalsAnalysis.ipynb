# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
API_KEY = "your_api_key"

# %%
base_url = "https://geokeo.com/database/town/ke/<page_number>/"
data = []
for page_number in range(1,18):
    url = base_url.replace("<page_number>", str(page_number))
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html.parser')
    table = soup.find("table")
    rows = table.find_all("tr") #rows + header
    headers = [header.text for header in rows[0].find_all("th")]
    for row in rows[1:]: #starts at 1 since index 0 is the header
        cells = row.find_all("td")
        data.append([cell.text for cell in cells])
    
    time.sleep(2)

df=pd.DataFrame(data, columns=headers)
columns = ['Name','Latitude','Longitude']
towns_df = df[columns]

# %%
towns_df.tail()
# Out:
#          Name             Latitude          Longitude
# 335  Wargadud   2.3102605997537387  40.36219429999999
# 336    Watamu   -3.349999999732027            40.0166
# 337    Watamu  -3.3537987359446166  40.00961499248949
# 338    Webuye    0.598035423557572  34.77322439130398
# 339    Webuye    0.607627999936463         34.7687756

# %%
#How to setup the url
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?
#location=<nairobi latitude and longitude>&radius=<radius to search in meters>&type=<business to search>&key=<api_key>

# %%
param_type = ["real_estate_agency","establishment"]
params = {
        "radius" : 3000,
        "key" : API_KEY
}


all_results = {}
# Lets create a datapipeline that usie googlemap apis to get data using locations etc
def agencies_establishments(): 
    # to not get a capping of 20 entries use next page token to get more values from the next page
    for _ , i in towns_df.iterrows():
        url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        all_results[i["Name"]] = []
        params["location"] = f"{i["Latitude"]}, {i["Longitude"]}"
        print(f"Working on {i["Name"]}")
        for par_type in param_type:
            params["type"] = par_type
            while True:   
                response = requests.get(url,params=params)
                data = response.json()
                all_results[i["Name"]].extend(data.get("results",[]))
                next_page_token = data.get("next_page_token")
                if not next_page_token:
                    break
                time.sleep(5)
                if "next_page_token" in data:
                    params["pagetoken"] = data["next_page_token"]
                print(f"Results fetched = {len(all_results[i["Name"]])}")
    
    print(f"Total results fetched = {len(all_results)}")
    main_df = format_data(all_results)
    return main_df

def format_data(all_results):
    #Lets look at that data
    df=[]
    for _,i in towns_df.iterrows():
        results = all_results.get(f"{i["Name"]}",[])
        for result in results:
            df.append({
                "operational" : result.get("business_status", "N/A"),
                "name" : result.get("name", "N/A"),
                "total_ratings" : result.get("user_ratings_total", "N/A"),
                "avg_rating" : result.get("rating", "N/A"),
                "vicinity" : result.get("vicinity", "N/A"),
                "types" : result.get("types", "N/A"),
                "lat" : result.get("geometry", {}).get("location",{}).get("lat","N/A"),
                "lng" : result.get("geometry", {}).get("location",{}).get("lng","N/A"),
            })
    data = pd.DataFrame(df)
    return data

data = agencies_establishments()
# Out:
# Working on Abageranso
# Working on Ahero
# Results fetched = 22
# Results fetched = 42
# Working on Amagoro
# Working on Athi River
# Working on Athi River
# Working on Awasi
# Working on Awendo
# Working on Babadogo
# Working on Bajumwali
# Working on Banana
# Working on Banana
# Working on Bangali
# Working on Baolala
# Working on Baragoi
# Working on Beled Hawo
# Working on Bisil
# Working on Bissil
# Working on Bomet
# Working on Bondo
# Working on Bondo
# Working on Bukura
# Working on Bulimbo/Harambee
# Working on Bumala
# Working on Buna
# Working on Bungoma
# Working on Bura East
# Working on Bura West
# Working on Busia
# Working on Busia
# Working on Butere
# Working on Butere
# Working on Bute Town
# Working on Chaka
# Working on Chakama
# Working on Chavakali
# Working on Chemelil
# Working on Chepilat Town
# Working on Chepkube
# Working on Chesongo Center
# Working on Chuka
# Working on Chuka
# Working on Dadaab
# Working on Dadaab
# Working on Dambas
# Working on Danaba
# Working on Dukana
# Working on Dukana
# Working on Dunto
# Working on Egerton
# Working on Eldama Ravine
# Working on Eldas
# Working on El Wak
# Working on El Wak
# Working on Emali
# Working on Emali
# Working on Emuhaya
# Working on Erestino
# Working on Faza
# Working on Flyover
# Working on Gambogi
# Working on Garba Tula
# Working on Garissa
# Working on Garsen
# Working on Gatundu
# Working on Gilgil
# Working on Gilgil
# Working on Githunguri
# Working on Githunguri
# Working on Githurai
# Working on Githurai
# Working on Gurar
# Working on Habswein
# Working on Hamisi
# Working on Hola
# Working on Hola
# Working on Holili
# Working on Homa Bay
# Working on Homa Bay
# Working on Hungai
# Working on Ibrahim Ure
# Working on Ifo Refugee Camp
# Working on Ihithe
# Working on Isebania
# Working on Isinya
# Working on Isiolo
# Working on Isiolo
# Working on Isiolo east
# Working on Iten
# Working on Iten
# Working on Joska
# Working on Juja
# Working on Juja
# Working on Kabarnet
# Working on Kabuku
# Working on Kajiado
# Working on Kajiado
# Working on Kakuma
# Working on Kalacha
# Working on Kalokol
# Working on Kaloleni
# Working on Kambaa
# Working on Kambiti Town
# Working on Kamulu
# Working on Kangoo
# Working on Kangundo
# Working on Kapenguria
# Working on Kapenguria
# Working on KAP JOSIAH CENTRE
# Working on Kapsabet
# Working on Kapsabet
# Working on Kapsoit
# Working on Kapsowar
# Working on Kaptara Center
# Working on Karatina
# Working on Karuri
# Working on Karurumo
# Working on Kasarani
# Working on Kathageri
# Working on Kathwana
# Working on Kathwana
# Working on Katito
# Working on Kebirigo
# Working on Kebirigo
# Working on Kendu Bay
# Working on Kenol
# Working on Kenol
# Working on Keroka
# Working on Keroka
# Working on Kerugoya
# Working on Khayega
# Working on Khorof Harar
# Working on Khwisero
# Working on Kiambu
# Working on Kibingoti Town
# Working on Kiboswa
# Working on Kibubuti
# Working on Kibwezi
# Working on Kibwezi
# Working on Kihancha
# Working on Kijabe
# Working on Kikuyu
# Working on Kikuyu
# Working on Kilala
# Working on Kilgoris
# Working on Kilifi
# Working on Kilifi
# Working on Kimende
# Working on Kimende
# Working on Kimilili
# Working on Kinungi
# Working on Kinungi
# Working on Kipsoit Center
# Working on Kirigiti
# Working on Kirigiti
# Working on Kiserian
# Working on Kiserian
# Working on Kisingitini
# Working on Kitale
# Working on Kitale
# Working on Kitengela
# Working on Kitengela
# Working on Kongoni
# Working on Korendile
# Working on Kosele
# Working on Kotulo
# Working on Kumpa
# Working on Kutulo Location
# Working on Kutus
# Working on Kutus
# Working on Kwale
# Working on Laisamis
# Working on Lamu
# Working on Lamu
# Working on Lare
# Working on Limuru
# Working on Limuru
# Working on Limuru
# Working on Lodwar
# Working on Loitokitok
# Working on Loitokitok
# Working on Loiyangalani
# Working on Loiyangalani
# Working on Lokichar
# Working on Lokichogio
# Working on Lokichogio
# Working on Lokitaung
# Working on Londiani
# Working on Londiani
# Working on Loolkuniyani
# Working on Lunyerere
# Working on Lwakhakha
# Working on Machesa
# Working on Machinery
# Working on Mado Gashi
# Working on Magadi
# Working on Magina
# Working on Mai Mahiu
# Working on Mai Maihu
# Working on Maji Mazuri
# Working on Makindu
# Working on Makindu
# Working on Maktau
# Working on Malaba
# Working on Mandera
# Working on Mandera
# Working on Mansa
# Working on Maragua
# Working on Maragua
# Working on Maralal
# Working on Maralal
# Working on Mariakani
# Working on Marsabit
# Working on Marsabit
# Working on Maseno
# Working on Masii
# Working on Masimba
# Working on Matano Manne
# Working on Matunda
# Working on Matungu
# Working on Maua
# Working on Mayoni
# Working on Mbale
# Working on Mbita
# Working on Migori
# Working on Mitunguu
# Working on Mlolongo
# Working on Mlolongo
# Working on Moi's Bridge
# Working on Molo
# Working on Molo
# Working on Moyale
# Working on Moyale
# Working on Moyale
# Working on Muhoroni
# Working on Mukarara
# Working on Mukumu
# Working on Mulot
# Working on Mumias
# Working on Mumias
# Working on Munyu
# Working on Murang'a
# Working on Murang'a
# Working on Musini
# Working on Mutitu
# Working on Mutituni
# Working on Mutomo
# Working on Mwatate
# Working on Mwingi
# Working on Mwingi Central location
# Working on Nadapal
# Working on Naivasha
# Working on Naivasha
# Working on Namalok
# Working on Namanga
# Working on Namanga
# Working on Nanyuki
# Working on Nanyuki
# Working on Narok
# Working on Narok
# Working on Naro Moru
# Working on Naro Moru
# Working on Ndenderu
# Working on Nduata
# Working on Ndugamano
# Working on Ndumberi
# Working on Ngatatoek
# Working on Ngegu
# Working on Ngong
# Working on Njabini
# Working on Njoro
# Working on Njoro
# Working on Nkubu
# Working on Ntulele
# Working on Nyahururu
# Working on Nyahururu
# Working on Nyambogi
# Working on Nyamira
# Working on Nyamira
# Working on Nyeri
# Working on Nyeri
# Working on Ogembo
# Working on Ol Kalou
# Working on Omboga
# Working on Ongata Rongai
# Working on Ongata Rongai
# Working on Oyugis
# Working on Raini
# Working on Rhamu
# Working on Riosiri Town Center
# Working on Rongai
# Working on Rongo
# Working on Ruaka
# Working on Ruaka
# Working on Ruaraka
# Working on Ruiru
# Working on Ruiru
# Working on Rumuruti
# Working on Sabatia
# Working on Sabuli
# Working on Sachangwan Center
# Working on Sagana
# Working on Sagana
# Working on Sarman
# Working on Sega
# Working on Shianda
# Working on Siaya
# Working on Sidindi
# Working on Sigalagala
# Working on Sigowet
# Working on Sindo
# Working on Softu
# Working on Sori
# Working on Stendi Kisa
# Working on Suneka
# Working on Suswa
# Working on Syokimau
# Working on Syokimau
# Working on Takaba
# Working on Tatu City
# Working on Taveta
# Working on Thika
# Working on Tundwa
# Working on Turitu
# Working on Ugunja
# Working on Ukunda
# Working on Vanga
# Working on Vihiga
# Working on Vihiga
# Working on Voi
# Working on Voi
# Working on Wagalla
# Working on Wajir
# Working on Wajir
# Working on Walda
# Working on Wamagana
# Working on Wargadud
# Working on Watamu
# Working on Watamu
# Working on Webuye
# Working on Webuye
# Total results fetched = 268

# %%
data.to_excel("towns_data_establishment_realEstate.xlsx", index=False)

# %%
first_10_data = list(all_results.values())[:10]
print(first_10_data)
# Out:
# [[{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 1.7729897, 'lng': 40.2959995}, 'viewport': {'northeast': {'lat': 1.774338680291502, 'lng': 40.2973484802915}, 'southwest': {'lat': 1.771640719708498, 'lng': 40.2946505197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Arbaqeranso Dispensary', 'photos': [{'height': 666, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117701363042387504274">Joseph Onyango (QuantiScale)</a>'], 'photo_reference': 'AXQCQNTPyFBaDbhpP4-YNVCKqjgrmKRUFq9Ub1dYOhvrRik70xTvMy5kHe9J2-fc7X4UdRfxR9ZVE6LpwjNaObeucDCZNsH3iXvvoyg_-Z1h1oulWms90VSXmkcYuTpD1Rxb6c2Y38ftXBWP55V2Hm9ufPBVvGB56YqlMrRVovUljkSwP6QAvpsRYR3LRVElcabEZjcW6OPHPBWhXfsjxlZuXFM0ffXwYuyiqgowqDHc4RKHg7EliUwWWHBhtxMXEUBULCqZncgPyVNtVrnAK5NJVX10x5m8uqZ_qHtW1m8kG37eXxKcFOYsBsyX2OSdDoQ0r_nm2X_jCfmSOFwwbV9t7j3AuNrEpxGm3Oe6QGFkGgw8QVGt3cqj2vKHF4KRGnRQ_D_ipkHrjgwqF1n4w3JqJmVOAYJwnIPkOM7q5OGN6qt3xSjyP72Ngk7zztpM5gLFu_fNHXaDB8MAuAaz9bm6Ui3mWKVFmRtdvAiPyndm6ds5azu1eKZq9Mp4uhvCdjKZYyLcRaN57KQ3o35rHxlBkjqt1fIGmid_ktr8axIqzokY0KAVppwSkWiDHcDdBt4UXUpuC8pvxUGoxbpdOdfszu9FsE2FGQM92cAVpCgqAwhQ8dcnKH62Vv493fXJekSuEbfn8A', 'width': 1184}], 'place_id': 'ChIJzf6ZUpai8hcRAyaL5Yi9LXg', 'reference': 'ChIJzf6ZUpai8hcRAyaL5Yi9LXg', 'scope': 'GOOGLE', 'types': ['health', 'point_of_interest', 'establishment'], 'vicinity': 'Q7FW+59X, Wajir'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 1.77, 'lng': 40.29000000000001}, 'viewport': {'northeast': {'lat': 1.771348980291502, 'lng': 40.2913489802915}, 'southwest': {'lat': 1.768651019708498, 'lng': 40.28865101970851}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'ARBA-QERAMSA PRI SCH', 'opening_hours': {'open_now': False}, 'photos': [{'height': 1080, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117101053123197958141">Hared Bash</a>'], 'photo_reference': 'AXQCQNSve3RSJloStfZJD1-I1seDBkZUUCRDHauI7_8xx1qLXDzsEiK2rT1JgCUnsjqX4sLlvoM5fs8dtStpeW7ksaCO1BoNe6FkfYcoCBWb610qFASEeFxaNYDVy68P4IUeFBX6BO4H9Zby6jqg6jqKtlWUL1mekDP_5nTDzvHC3-VGpRr3RlxofI9vIvtrEBMZF6G-vtfacvs2_whyKIFPV4avyjtnTvZ9WH_9LybHU2ScYsMGstSCZx15WKnC7fK-AK4SwkljzSNffHLvBaOQLDw7awRiEw69gxdyq82C1xcdV5FtLCI4VQNqzq0uQO8gIr9nZn61wlEK_g2TDWh71nn045QCAf7zR9AsnGOZIialS28jeEVJGV3JwYiHPitWgiBDumQ5q2LNdlbCdw4AGo0FRHF7wv-QOn2RpBMiVhrBPoVj-uA5J3mjDYf6fQWtXfFRprcFNHYAe0Rc2SkecAtBq83TAUG5zCw7uBtANjtmuGTI73FdY7yfaOkanKaaW3iDiYrEZaieoWRLFtBRWlPqp-HbYnx_Liz5FYBSGw4rvCsxxNMX0JvYOEp60sMd39OhQ4facj7-uIB2y2LbKX1VHb9GveXnx_2UT2Z4Yg8N8pXTtRGWwpNvqPagzeQFdkV9zcxD', 'width': 1920}], 'place_id': 'ChIJ7Tj-o5ij8hcR7MPzH0QGVII', 'plus_code': {'compound_code': 'Q79Q+XX Wajir, Kenya', 'global_code': '6HH2Q79Q+XX'}, 'rating': 5, 'reference': 'ChIJ7Tj-o5ij8hcR7MPzH0QGVII', 'scope': 'GOOGLE', 'types': ['school', 'point_of_interest', 'establishment'], 'user_ratings_total': 1, 'vicinity': 'WAJIR-BOR, Wajir'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 1.7625348, 'lng': 40.2934477}, 'viewport': {'northeast': {'lat': 1.763883780291502, 'lng': 40.2947966802915}, 'southwest': {'lat': 1.761185819708498, 'lng': 40.29209871970851}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png', 'icon_background_color': '#4DB546', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet', 'name': 'Arbaqeramso water pan', 'photos': [{'height': 4000, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113493658294890114533">Hassan Ahmed Qumbi</a>'], 'photo_reference': 'AXQCQNTppVzMbo1soON-ICdPChQOkZuxRu98OYdb83e4J38L0LhqPHW7SzY6XoeM_2XzaICLnni7OaxN9BUQJ3iypDwDXPRx0uS4h3qkgt1eFIKw2 ...
